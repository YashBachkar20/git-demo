# %%
#Import libraries
import numpy as np                    # linear algebra /as computational purposes
import pandas as pd                   # Data processing/manipulation, CSV file I/O 
import matplotlib.pyplot as plt       # Broding purposes
import seaborn as sns                 # 
import plotly.figure_factory as ff
import warnings

# %% [markdown]
# ## Load the data

# %%
NYC= pd.read_csv('AB_NYC_2019.csv')
NYC
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# We have Data with 16 attributes and 48895 records.

# %% [markdown]
# ## Display structure and summary report.

# %%
NYC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
NYC.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
NYC.shape
# Out:
# (48895, 16)

# %% [markdown]
# # Check data types of each column and ensure whether the data types for each of the attributes are appropriate, if not make appropriate corrections.

# %%
NYC.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ##  Display NULL values for each of the columns

# %%
NYC.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# In this dataset we have null values in columns name,host-id,last_review and reviews_per_month

# %% [markdown]
# # Find out missing values and replace them for the applicable columns.

# %% [markdown]
# #### 1: We got missing values from columns name, host_name, last_review.
# #### 2: The use of columns is not good for our data because columns got many missing values which is not appropriate.
# #### 3: Instead of replacing them we are going to dropping that columns.

# %%
NYC.drop(['name','host_name','last_review'], axis = 1, inplace = True)
NYC
# Out:
#              id   host_id neighbourhood_group       neighbourhood  latitude  \
# 0          2539      2787            Brooklyn          Kensington  40.64749
# 1          2595      2845           Manhattan             Midtown  40.75362
# 2          3647      4632           Manhattan              Harlem  40.80902
# 3          3831      4869            Brooklyn        Clinton Hill  40.68514
# 4          5022      7192           Manhattan         East Harlem  40.79851
# ...         ...       ...                 ...                 ...       ...
# 48890  36484665   8232441            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891  36485057   6570630            Brooklyn            Bushwick  40.70184
# 48892  36485431  23492952           Manhattan              Harlem  40.81475
# 48893  36485609  30985759           Manhattan      Hell's Kitchen  40.75751
# 48894  36487245  68119814           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# #### replacing all NaN values in 'reviews_per_month' with 0

# %%
NYC.fillna({'reviews_per_month':0}, inplace=True)

NYC.reviews_per_month.isnull().sum()
# Out:
# 0

# %% [markdown]
# # Check which hosts (IDs) have the most listings on Airbnb platform and taking advantage of this service. Display in ascending order.

# %%
advan_sev = NYC.host_id.value_counts().head(15).sort_values()
advan_sev
# Out:
# 190921808     47
# 2856748       49
# 205031545     49
# 120762452     50
# 7503643       52
# 1475015       52
# 200380610     65
# 22541573      87
# 61391963      91
# 16098958      96
# 12243051      96
# 137358866    103
# 30283594     121
# 107434423    232
# 219517861    327
# Name: host_id, dtype: int64

# %% [markdown]
# # Plot a bar graph for Host_ID vs Count of Listings.

# %%
grouped = NYC.groupby('host_id').count()['id']
grouped = grouped.sort_values(ascending = False)
N = 50
grouped = grouped[:N]


grouped.plot(kind = 'bar', figsize = (15, 8))

plt.title("Count of Listings by Host ID")
plt.xlabel("Host ID")
plt.ylabel("Count of Listings")

plt.show()

# %% [markdown]
# From bar graph we the Host_id 219517861 with maximum listing count with more than 300 count
#
# and minimum count of less than 50 with Host-id 260639745

# %% [markdown]
# # Based on Room_Type, prepare a bar graph for neighbourhood vs Count of Listings

# %%
nbh = NYC.loc[NYC['neighbourhood'].isin(['Williamsburg','Bedford-Stuyvesant','Harlem','Bushwick','Upper West Side','Hell\'s Kitchen','East Village','Upper East Side','Crown Heights','Midtown'])]

grouped = nbh.groupby(['room_type', 'neighbourhood']).count()['host_id']
grouped = grouped.reset_index()
pivot = grouped.pivot(index = 'neighbourhood', columns = 'room_type', values = 'host_id')
print(pivot)
pivot.plot(kind = 'bar', figsize = (15, 8))

plt.title("Count of Listings by Room Type and Neighbourhood")
plt.xlabel("Neighbourhood")
plt.ylabel("Count of Listings")

plt.show()
# Out:
# room_type           Entire home/apt  Private room  Shared room
# neighbourhood
# Bedford-Stuyvesant             1591          2038           85
# Bushwick                        678          1719           68
# Crown Heights                   759           780           25
# East Village                   1170           660           23
# Harlem                         1036          1573           49
# Hell's Kitchen                 1187           672           99
# Midtown                        1100           422           23
# Upper East Side                1310           441           47
# Upper West Side                1256           675           40
# Williamsburg                   1891          1997           32

# %% [markdown]
# We seen that,
#
# Bedford-stuyvesant and Williamsburg have max listing count for Private Room type
#
# Williamsburg have max listing count for entire home/apt Room type
#
# Minimum listing count for Shared room type for any Neighbou
